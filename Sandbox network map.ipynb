# %%
# Requirements
import pandas as pd
from geopy.geocoders import Nominatim
import time
import folium
from folium.plugins import AntPath
from IPython.display import display, clear_output
import ipywidgets as widgets
import requests

# %%
# Importing data

# All Countries
path_top = "https://raw.githubusercontent.com/a-sofia-p/textile/refs/heads/main/Data/worn_clothing_exports/Top_exporters.csv"
df_top_exporters = pd.read_csv(path_top)
df_top_exporters = pd.read_csv(path_top)
df_top_exporters.index += 1

# %%
df_top_exporters
# Out:
#     Year                 r1_country r1_quantity                 r2_country  \
# 1   2015  United States of America      718,597                   Germany
# 2   2016  United States of America      753,882                   Germany
# 3   2017  United States of America      788,404                   Germany
# 4   2018  United States of America      756,380                   Germany
# 5   2019  United States of America      765,872                   Germany
# 6   2020  United States of America      621,784                   Germany
# 7   2021                     China      440,048  United States of America
# 8   2022                     China      603,666  United States of America
# 9   2023                     China      762,057  United States of America
# 10  2024                     China    1,148,954  United States of America
#
#    r2_quantity           r3_country r3_quantity           r4_country  \
# 1      535,638      United Kingdom      351,179  Korea, Republic of
# ...

# %%
# USA
path_usa = "https://raw.githubusercontent.com/a-sofia-p/textile/refs/heads/main/Data/worn_clothing_exports/USA_exports.csv"
df_usa = pd.read_csv(path_usa)
df_usa.index += 1
df_usa
# Out:
#     Year r1_country r1_quantity r2_country r2_quantity r3_country r3_quantity  \
# 1   2015     Canada     155,912      India      98,077  Guatemala      67,739
# 2   2016     Canada     152,385      India     117,840  Guatemala      69,779
# 3   2017     Canada     143,218      India     118,965  Guatemala      73,583
# 4   2018     Canada     135,561      India      97,647  Guatemala      79,261
# 5   2019     Canada     127,519      India      99,546  Guatemala      87,848
# 6   2020     Canada      81,240      India      71,225  Guatemala      80,138
# 7   2021  Guatemala     116,613     Canada      98,107      India      53,138
# 8   2022  Guatemala     118,246     Canada      96,845      India      63,027
# 9   2023  Guatemala     117,464     Canada      85,171      India      72,168
# 10  2024  Guatemala     116,116      India      82,660     Canada      74,358
#
#    r4_country r4_uantity r5_country r5_quantity
# 1       Chile     54,688   Honduras      22,051
# ...

# %%
# Load country coordinates
df_coords = pd.read_csv('https://raw.githubusercontent.com/a-sofia-p/textile/refs/heads/main/Data/Complete/country_coordinates.csv')

# Transform to dict to iterate over
coord_dict = df_coords.set_index('country')[['latitude', 'longitude']].T.to_dict()
