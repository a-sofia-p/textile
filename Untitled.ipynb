# %%
# Requirements
import pandas as pd

# %%
# Importing data

# All Countries
path_all = "C:/Users/Sofia/Desktop/Projects/Trade_Map_Export_Growth_All.txt"
df_all = pd.read_csv(path_all)

# %%
df_all.head(6)
# Out:
#   Exporters\tExported growth in quantity between 2015-2016  \
# 0  World\tN/A\tN/A\tN/A\tN/A\tN/A\tN/A\tN/A\tN/A\...
# 1  China\t8\t67\t22\t15\t-14\t51\t37\t26\t51\t114...
# 2  United States of America\t5\t5\t-4\t1\t-19\t17...
# 3  United Kingdom\t1\t5\t7\tN/A\tN/A\t22\t16\t1\t...
# 4  Germany\t-3\t-2\t1\t3\t-8\t5\t-7\t-6\t-9\t4130...
# 5  Pakistan\t5\t-8\t34\t66\t356\t43\t-6\t-7\t13\t...
#
#     %\tExported growth in quantity between 2016-2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#     %\tExported growth in quantity between 2017-2018  \
# 0                                                NaN
# 1                                                NaN
# ...
